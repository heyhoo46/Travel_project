# %%
from datacollect import collect_place, collect_restaurant# 이렇게 해야 임폴트 됨 왜?

# %%
# 하나로 모으기 위한 리스트
category_list = [] # 카테고리(박물관, 테마파크, 산, 해변, 시장 오름 등등)
place_list = [] # 장소이름
score_list = [] # 별점
address_list = [] # 주소
bushour_list = [] # 영업시간(bussiness hour)
comment_list = [] # 개요 또는 리뷰

# %%
search1 = "제주도 테마파크"
themapark = collect_place(search1, 1)

category_list.extend(themapark[0])
place_list.extend(themapark[1])
score_list.extend(themapark[2])
address_list.extend(themapark[3])
bushour_list.extend(themapark[4])
comment_list.extend(themapark[5])
# Out:
# 제주도 테마파크폴더가 존재합니다
# 스폰서 0 개 제외합니다.
# 스폰서 아닙니다.
# 정상 영업합니다.
# 신화테마파크
# 3.9
# 개요: 신화테마파크는 2017년 9월 30일에 개장한 대한민국 제주특별자치도에 있는 테마파크이며, 제주신화월드에 위치해 있다. 대한민국의 주요 인기 애니메이션들을 테마로 한 테마파크이다. 위키백과
# 주소: 제주특별자치도 서귀포시 특별자치도, 안덕면 신화역사로304번길 98
# 금요일 오전 10:00~오후 8:00
# 토요일 오전 10:00~오후 8:00
# 일요일 오전 10:00~오후 8:00
# 월요일 오전 10:00~오후 8:00
# 화요일 오전 10:00~오후 8:00
# 수요일 오전 10:00~오후 8:00
# 목요일 오전 10:00~오후 8:00
# 신화테마파크.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 에코랜드
# 4.3
# 개요: 에코랜드는 제주특별자치도 제주시 조천읍 대흘리에 위치한 테마파크이다. 에코랜드 테마파크와 에코랜드 골프&리조트으로 나뉜다. 테마파크는 기차를 타며 숲을 구경할 수 있게 되어 있으며 숲은 각각 4개의 역으로 구성되어있다. 기차를 타고 간이역으로 내려 관람할 수 있다. 위키백과
# 주소: 제주특별자치도 제주시 특별자치도, 조천읍 번영로 1278-169 KR
# 금요일 오전 8:30~오후 6:30
# 토요일 오전 8:30~오후 6:30
# 일요일 오전 8:30~오후 6:30
# 월요일 오전 8:30~오후 6:30
# 화요일 오전 8:30~오후 6:30
# 수요일 오전 8:30~오후 6:30
# 목요일 오전 8:30~오후 6:30
# 에코랜드.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 9.81 파크
# 4.4
# 해당 장소에 대한 설명이 없습니다.
# 주소: 제주특별자치도 제주시 애월읍 천덕로 880-24
# 금요일 오전 9:00~오후 6:00
# ...

# %%
import pandas as pd

try:  
    # 데이터 저장
    data_dic = {"category":themapark[0],
        "place":themapark[1],
        "score":themapark[2],
        "address":themapark[3],
        "bushour":themapark[4],
        "summary":themapark[5]}
    df = pd.DataFrame(data_dic)
    df.to_csv("제주도_테마파크.csv", encoding='utf-8-sig')
    print("제주도_테마파크.csv 파일 변환 완료")

except Exception as e:
    print(f"오류 발생: {e}") 
    print("제주도_테마파크.csv 파일 변환 실패")
# Out:
# 제주도_테마파크.csv 파일 변환 완료

# %%
search1 = "제주도 산"
mountain = collect_place(search1, 1)

category_list.extend(mountain[0])
place_list.extend(mountain[1])
score_list.extend(mountain[2])
address_list.extend(mountain[3])
bushour_list.extend(mountain[4])
comment_list.extend(mountain[5])
# Out:
# 제주도 산폴더가 존재합니다
# 스폰서 0 개 제외합니다.
# 산입니다.
# 스폰서 아닙니다.
# 정상 영업합니다.
# 산방산
# 4.4
# 개요: 산방산은 대한민국 제주특별자치도 서귀포시 안덕면 사계리에 있는 산이다. '산방'이라는 말은 굴이 있는 산을 뜻한다. 높이는 해발 395m이며, 남쪽 해발 150m 쯤에 해식동굴이 있어서 산방산이라 이름을 지었다. 대한민국의 명승으로 지정되었다. 위키백과
# 해당 장소에 대한 주소 없습니다.
# 해당 장소에 대한 영업시간 없습니다.
# 산방산.jpg 저장 완료
# ------------------------
# 산입니다.
# 스폰서 아닙니다.
# 정상 영업합니다.
# 한라산
# 4.7
# 개요: 한라산은 대한민국 제주도 중앙부에 있는 해발 1,947.06m, 면적 약 1,820km²의 화산으로, 제주도의 면적 대부분을 차지하고 있다. 정상에 백록담이라는 화산호가 있는데, 백록담이라는 이름은 흰 사슴이 물을 먹는 곳이라는 뜻에서 왔다고 전해진다. 위키백과
# 해당 장소에 대한 주소 없습니다.
# 해당 장소에 대한 영업시간 없습니다.
# 한라산.jpg 저장 완료
# ------------------------
# 산입니다.
# 스폰서 아닙니다.
# 정상 영업합니다.
# 영주산
# 4.6
# 개요: 영주산은 제주특별자치도 서귀포시 표선면 성읍1리에 위치한 오름이다. 높이가 326.4m로 산체가 비교적 크고 동북쪽으로 터진 말굽형 분화구의 형태를 지니고 있다. 사면 전체가 초지로 이루어져 있고 동쪽 아래 기슭에는 성읍 마을 공동묘지가 있다. 위키백과
# 해당 장소에 대한 주소 없습니다.
# 해당 장소에 대한 영업시간 없습니다.
# 영주산.jpg 저장 완료
# ------------------------
# 산입니다.
# 스폰서 아닙니다.
# 정상 영업합니다.
# 고근산
# 4.6
# ...

# %%
import pandas as pd

try:  
    # 데이터 저장
    data_dic = {"category":mountain[0],
        "place":mountain[1],
        "score":mountain[2],
        "address":mountain[3],
        "bushour":mountain[4],
        "summary":mountain[5]}
    df = pd.DataFrame(data_dic)
    df.to_csv("제주도_산.csv", encoding='utf-8-sig')
    print("제주도_산.csv 파일 변환 완료")

except Exception as e:
    print(f"오류 발생: {e}") 
    print("제주도_산.csv 파일 변환 실패")
# Out:
# 제주도_산.csv 파일 변환 완료

# %%
search1 = "제주도 박물관"
museum = collect_place(search1, 1)

category_list.extend(museum[0])
place_list.extend(museum[1])
score_list.extend(museum[2])
address_list.extend(museum[3])
bushour_list.extend(museum[4])
comment_list.extend(museum[5])
# Out:
# 제주도 박물관폴더가 존재합니다
# 스폰서 0 개 제외합니다.
# 스폰서 아닙니다.
# 정상 영업합니다.
# 국립제주박물관
# 4.3
# 개요: 국립제주박물관은 국립중앙박물관의 소속기관이다. 1997년 3월 20일 발족하였으며, 제주특별자치도 제주시 일주동로 17에 위치하고 있다. 관장은 학예연구관으로 보한다. 위키백과
# 주소: 제주특별자치도 제주시 일주동로 17
# 금요일 오전 9:00~오후 6:00
# 토요일 오전 9:00~오후 6:00
# 일요일 오전 9:00~오후 6:00
# 월요일 휴무일
# 화요일 오전 9:00~오후 6:00
# 수요일 오전 9:00~오후 6:00
# 목요일 오전 9:00~오후 6:00
# 국립제주박물관.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 제주특별자치도 민속자연사박물관
# 4.2
# 개요: 제주특별자치도 민속자연사박물관은 제주특별자치도의 민속문화와 자연사를 보존하기 위해 제주특별자치도청 산하에 설치된 사업소이다. 박물관장은 지방서기관이나 지방학예연구관, 지방농업연구관, 지방환경연구관, 또는 지방임기제공무원으로 보한다. 위키백과
# 주소: 제주특별자치도 제주시 삼성로 40
# 금요일 오전 9:00~오후 6:00
# 토요일 오전 9:00~오후 6:00
# 일요일 오전 9:00~오후 6:00
# 월요일 휴무일
# 화요일 오전 9:00~오후 6:00
# 수요일 오전 9:00~오후 6:00
# 목요일 오전 9:00~오후 6:00
# 제주특별자치도 민속자연사박물관.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 제주해녀박물관
# 4.3
# 개요: 해녀박물관은 제주특별자치도의 해녀 문화를 전승·보존하기 위해 제주특별자치도청 해양수산국 해양산업과에서 관리하는 박물관이다. 제주특별자치도 제주시 구좌읍 해녀박물관길 26에 위치하고 있다. 위키백과
# ...

# %%
import pandas as pd

try:  
    # 데이터 저장
    data_dic = {"category":museum[0],
        "place":museum[1],
        "score":museum[2],
        "address":museum[3],
        "bushour":museum[4],
        "summary":museum[5]}
    df = pd.DataFrame(data_dic)
    df.to_csv("제주도_박물관.csv", encoding='utf-8-sig')
    print("제주도_박물관.csv 파일 변환 완료")

except Exception as e:
    print(f"오류 발생: {e}") 
    print("제주도_박물관.csv 파일 변환 실패")
# Out:
# 제주도_박물관.csv 파일 변환 완료

# %%
search1 = "제주도 해변"
beach = collect_place(search1, 1)

category_list.extend(beach[0])
place_list.extend(beach[1])
score_list.extend(beach[2])
address_list.extend(beach[3])
bushour_list.extend(beach[4])
comment_list.extend(beach[5])
# Out:
# 제주도 해변폴더가 존재합니다
# 스폰서 0 개 제외합니다.
# 스폰서 아닙니다.
# 정상 영업합니다.
# 함덕해수욕장
# 4.5
# 개요: 함덕해수욕장은 제주특별자치도 제주시 조천읍 함덕리에 있는 해변이다. 바로 옆에 위치한 서우봉 때문에 함덕서우봉해변이라고도 불린다. 위키백과
# 해당 장소에 대한 주소 없습니다.
# 해당 장소에 대한 영업시간 없습니다.
# 함덕해수욕장.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 금능해수욕장
# 4.6
# 해당 장소에 대한 설명이 없습니다.
# 해당 장소에 대한 주소 없습니다.
# 해당 장소에 대한 영업시간 없습니다.
# 금능해수욕장.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 협재해변
# 4.6
# 해당 장소에 대한 설명이 없습니다.
# 주소: 제주특별자치도 제주시 한림읍 한림로 329-10
# 금요일 24시간 영업
# 토요일 24시간 영업
# 일요일 24시간 영업
# 월요일 24시간 영업
# 화요일 24시간 영업
# 수요일 24시간 영업
# 목요일 24시간 영업
# 협재해변.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 중문 색달해수욕장
# 4.3
# 개요: 영어에서 번역됨-중문색달해변은 제주특별자치도 서귀포시 색달동에 있는 해변이다. 해변의 길이는 560m, 폭은 50m이며, 모래는 검은색, 흰색, 빨간색, 회색 등 다양한 색상을 띠고 있습니다. 위키백과(영어)
# 해당 장소에 대한 주소 없습니다.
# 해당 장소에 대한 영업시간 없습니다.
# 중문 색달해수욕장.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 월정리 해수욕장
# 4.4
# 해당 장소에 대한 설명이 없습니다.
# 해당 장소에 대한 주소 없습니다.
# 해당 장소에 대한 영업시간 없습니다.
# ...

# %%
import pandas as pd

try:  
    # 데이터 저장
    data_dic = {"category":beach[0],
        "place":beach[1],
        "score":beach[2],
        "address":beach[3],
        "bushour":beach[4],
        "summary":beach[5]}
    df = pd.DataFrame(data_dic)
    df.to_csv("제주도_해변.csv", encoding='utf-8-sig')
    print("제주도_해변.csv 파일 변환 완료")

except Exception as e:
    print(f"오류 발생: {e}") 
    print("제주도_해변.csv 파일 변환 실패")
# Out:
# 제주도_해변.csv 파일 변환 완료

# %%
search1 = "제주시 시장"
market = collect_place(search1, 1)

category_list.extend(market[0])
place_list.extend(market[1])
score_list.extend(market[2])
address_list.extend(market[3])
bushour_list.extend(market[4])
comment_list.extend(market[5])
# Out:
# 제주시 시장폴더가 존재합니다
# 스폰서 0 개 제외합니다.
# 스폰서 아닙니다.
# 정상 영업합니다.
# 제주동문시장
# 4.1
# 해당 장소에 대한 설명이 없습니다.
# 주소: 제주특별자치도 제주시 특별자치도 관덕로14길 20
# 금요일 오전 8:00~오후 9:00
# 토요일 오전 8:00~오후 9:00
# 일요일 오전 8:00~오후 9:00
# 월요일 오전 8:00~오후 9:00
# 화요일 오전 8:00~오후 9:00
# 수요일 오전 8:00~오후 9:00
# 목요일 오전 8:00~오후 9:00
# 제주동문시장.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 동문재래시장
# 4.1
# 개요: 제주 동문재래시장은 대한민국 제주특별자치도 제주시에 위치한 재래시장이다. 제주도에서 가장 오래된 상설 재래시장이다. 위키백과
# 주소: 제주특별자치도 제주시 동문로4길 9
# 금요일 오전 8:00~오후 9:00
# 토요일 오전 8:00~오후 9:00
# 일요일 오전 8:00~오후 9:00
# 월요일 오전 8:00~오후 9:00
# 화요일 오전 8:00~오후 9:00
# 수요일 오전 8:00~오후 9:00
# 목요일 오전 8:00~오후 9:00
# 동문재래시장.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 제주민속오일시장
# 4.2
# 해당 장소에 대한 설명이 없습니다.
# 주소: 제주특별자치도 제주시 오일장서길 26
# 금요일 오전 7:00~오후 6:00
# 토요일 오전 7:00~오후 6:00
# 일요일 휴무일
# 월요일 오전 7:00~오후 6:00
# 화요일 오전 7:00~오후 6:00
# 수요일 오전 7:00~오후 6:00
# 목요일 오전 7:00~오후 6:00
# 제주민속오일시장.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 동문수산시장
# 4.2
# ...

# %%
import pandas as pd

try:  
    # 데이터 저장
    data_dic = {"category":market[0],
        "place":market[1],
        "score":market[2],
        "address":market[3],
        "bushour":market[4],
        "summary":market[5]}
    df = pd.DataFrame(data_dic)
    df.to_csv("제주도_시장.csv", encoding='utf-8-sig')
    print("제주도_시장.csv 파일 변환 완료")

except Exception as e:
    print(f"오류 발생: {e}") 
    print("제주도_시장.csv 파일 변환 실패")
# Out:
# 제주도_시장.csv 파일 변환 완료

# %%
search1 = "제주도 오름"
oleum = collect_place(search1, 4)

category_list.extend(oleum[0])
place_list.extend(oleum[1])
score_list.extend(oleum[2])
address_list.extend(oleum[3])
bushour_list.extend(oleum[4])
comment_list.extend(oleum[5])
# Out:
# 제주도 오름폴더가 존재합니다
# 스폰서 2 개 제외합니다.
# 스폰서 아닙니다.
# 정상 영업합니다.
# 궷물오름
# 4.2
# 해당 장소에 대한 설명이 없습니다.
# 주소: 제주특별자치도 제주시 애월읍 유수암리
# 금요일 24시간 영업
# 토요일 24시간 영업
# 일요일 24시간 영업
# 월요일 24시간 영업
# 화요일 24시간 영업
# 수요일 24시간 영업
# 목요일 24시간 영업
# 궷물오름.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 군산오름
# 4.6
# 해당 장소에 대한 설명이 없습니다.
# 주소: 제주특별자치도 서귀포시 안덕면 창천리 564 제주특별자치도
# 해당 장소에 대한 영업시간 없습니다.
# 군산오름.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 거문오름
# 4.6
# 개요: 거문오름은 대한민국 제주특별자치도의 제주시 조천읍과 서귀포시 남원읍, 서귀포시 표선면의 경계를 이루고 있는 오름이다. 정상의 분화구의 형태는 등성이를 기준으로 동, 서로 나뉘어 있는 복합형식으로 되어 있다. 위키백과
# 주소: 제주특별자치도 제주시 조천읍 선흘리
# 금요일 오전 9:00~오후 1:00
# 토요일 오전 9:00~오후 1:00
# 일요일 오전 9:00~오후 1:00
# 월요일 오전 9:00~오후 1:00
# 화요일 오전 9:00~오후 1:00
# 수요일 오전 9:00~오후 1:00
# 목요일 오전 9:00~오후 1:00
# 거문오름.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 금오름
# 4.5
# ...

# %%
import pandas as pd

try:  
    # 데이터 저장
    data_dic = {"category":oleum[0],
        "place":oleum[1],
        "score":oleum[2],
        "address":oleum[3],
        "bushour":oleum[4],
        "summary":oleum[5]}
    df = pd.DataFrame(data_dic)
    df.to_csv("제주도_오름.csv", encoding='utf-8-sig')
    print("제주도_오름.csv 파일 변환 완료")

except Exception as e:
    print(f"오류 발생: {e}") 
    print("제주도_오름.csv 파일 변환 실패")
# Out:
# 제주도_오름.csv 파일 변환 완료

# %%
search1 = "제주시 둘레길"
dullegil = collect_place(search1, 4)

category_list.extend(dullegil[0])
place_list.extend(dullegil[1])
score_list.extend(dullegil[2])
address_list.extend(dullegil[3])
bushour_list.extend(dullegil[4])
comment_list.extend(dullegil[5])
# Out:
# 스폰서 0 개 제외합니다.
# 스폰서 아닙니다.
# 정상 영업합니다.
# 송악산 둘레길
# 4.7
# 해당 장소에 대한 설명이 없습니다.
# 주소: 제주특별자치도 서귀포시 대정읍 송악관광로 421-1
# 해당 장소에 대한 영업시간 없습니다.
# 송악산 둘레길.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 서우봉 둘레길
# 4.6
# 해당 장소에 대한 설명이 없습니다.
# 주소: 제주특별자치도 제주시 조천읍 함덕리 199
# 금요일 오전 8:30~오후 7:30
# 토요일 오전 8:30~오후 7:30
# 일요일 오전 8:30~오후 7:30
# 월요일 오전 8:30~오후 7:30
# 화요일 오전 8:30~오후 7:30
# 수요일 오전 8:30~오후 7:30
# 목요일 오전 7:30~오후 7:30
# 서우봉 둘레길.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# [제주올레 13코스] 용수-저지 올레
# 4.5
# 해당 장소에 대한 설명이 없습니다.
# 주소: 제주특별자치도 제주시 한경면 용수리
# 금요일 24시간 영업
# 토요일 24시간 영업
# 일요일 24시간 영업
# 월요일 24시간 영업
# 화요일 24시간 영업
# 수요일 24시간 영업
# 목요일 24시간 영업
# [제주올레 13코스] 용수-저지 올레.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# [제주올레 15A코스] 한림-고내 올레
# 4.5
# 해당 장소에 대한 설명이 없습니다.
# 주소: 제주특별자치도 제주시 한림읍 한림해안로 196
# 금요일 24시간 영업
# 토요일 24시간 영업
# 일요일 24시간 영업
# 월요일 24시간 영업
# 화요일 24시간 영업
# 수요일 24시간 영업
# 목요일 24시간 영업
# [제주올레 15A코스] 한림-고내 올레.jpg 저장 완료
# ...

# %%
import pandas as pd

try:  
    # 데이터 저장
    data_dic = {"category":dullegil[0],
        "place":dullegil[1],
        "score":dullegil[2],
        "address":dullegil[3],
        "bushour":dullegil[4],
        "summary":dullegil[5]}
    df = pd.DataFrame(data_dic)
    df.to_csv("제주도_둘레길.csv", encoding='utf-8-sig')
    print("제주도_둘레길.csv 파일 변환 완료")

except Exception as e:
    print(f"오류 발생: {e}") 
    print("제주도_둘레길.csv 파일 변환 실패")
# Out:
# 제주도_둘레길.csv 파일 변환 완료

# %%
import pandas as pd

try:  
    # 데이터 저장
    data_dic = {"category":category_list,
        "place":place_list,
        "score":score_list,
        "address":address_list,
        "bushour":bushour_list,
        "summary":comment_list}
    df = pd.DataFrame(data_dic)
    df.to_csv(f"{search1.split()[0]}_명소.csv", encoding='utf-8-sig')
    print(f"{search1.split()[0]}_명소.csv 파일 변환 완료")

except Exception as e:
    print(f"오류 발생: {e}") 
    print(f"{search1.split()[0]}_명소.csv 파일 변환 실패")
# Out:
# 제주시_명소.csv 파일 변환 완료

# %%
#--------------------------------------------------------

# %%
# 하나로 모으기 위한 리스트
cat_list = [] # 카테고리(박물관, 테마파크, 산, 해변, 시장 오름 등등)
pl_list = [] # 장소이름
sc_list = [] # 별점
ad_list = [] # 주소
bh_list = [] # 영업시간(bussiness hour)
comm_list = [] # 개요 또는 리뷰

# %%
search1 = "제주시 맛집"
restaurant = collect_restaurant(search1, 3, 200, 4.2)

cat_list.extend(restaurant[0])
pl_list.extend(restaurant[1])
sc_list.extend(restaurant[2])
ad_list.extend(restaurant[3])
bh_list.extend(restaurant[4])
comm_list.extend(restaurant[5])
# Out:
# 제주시 맛집폴더가 존재합니다
# 스폰서 아닙니다.
# 정상 영업합니다.
# 고집돌우럭 제주공항점
# 4.6
# 제주특별자치도 제주시 특별자치도, 임항로 30
# "음식점 개인적인 감상으로는 3/5이였습니다."
# 금요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# 토요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# 일요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# 월요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# 화요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# 수요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# 목요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# 고집돌우럭 제주공항점.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 곰막식당
# 4.3
# 제주특별자치도 제주시 구좌읍 구좌해안로 64
# "손님도 끈임 없이 와서 재료가 신선해요!"
# 금요일 오전 9:30~오후 9:00
# 토요일 오전 9:30~오후 9:00
# 일요일 오전 9:30~오후 9:00
# 월요일 오전 9:30~오후 9:00
# 화요일 오전 9:30~오후 9:00
# 수요일 오전 9:30~오후 9:00
# 목요일 오전 9:30~오후 9:00
# 곰막식당.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 불특정식당
# 4.5
# 제주특별자치도 제주시 원노형6길 2 1 층
# "커플은 주로 다찌석, 3인이상부터는 테이블로 안내해주는것 같았습니다."
# 금요일 오전 12:00~오후 10:00
# 토요일 오전 12:00~오후 10:00
# 일요일 오전 12:00~오후 10:00
# 월요일 오전 12:00~오후 10:00
# 화요일 오전 12:00~오후 10:00
# 수요일 오전 12:00~오후 10:00
# 목요일 오전 12:00~오후 10:00
# ...

# %%
search1 = "서귀포시 맛집"
restaurant = collect_restaurant(search1, 3, 200, 4.2)

cat_list.extend(restaurant[0])
pl_list.extend(restaurant[1])
sc_list.extend(restaurant[2])
ad_list.extend(restaurant[3])
bh_list.extend(restaurant[4])
comm_list.extend(restaurant[5])
# Out:
# 서귀포시 맛집폴더가 존재합니다
# 스폰서 아닙니다.
# 정상 영업합니다.
# 중문그때그집 서귀포본점
# 4.8
# 제주특별자치도 서귀포시 특별자치도, 상예로 181-28 KR
# "3년만에 다시 왔어요 역시 후회하지 않는 맛"
# 금요일 오전 9:30~오후 10:30
# 토요일 오전 9:30~오후 10:30
# 일요일 오전 9:30~오후 10:30
# 월요일 오전 9:30~오후 10:30
# 화요일 오전 9:30~오후 10:30
# 수요일 오전 9:30~오후 10:30
# 목요일 오전 9:30~오후 10:30
# 8주 전에 이 비즈니스에서 업데이트함
# 중문그때그집 서귀포본점.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 뽈살집
# 4.6
# 제주특별자치도 서귀포시 특별자치도 중앙동 중정로91번길 41
# "맛은 있었지만 가격이 ㅎㄷㄷ 2인분에 갈치 5토막."
# 금요일 오후 3:00~오전 12:00
# 토요일 오후 3:00~오전 12:00
# 일요일 오후 3:00~오전 12:00
# 월요일 오후 3:00~오전 12:00
# 화요일 오후 3:00~오전 12:00
# 수요일 오후 3:00~오전 12:00
# 목요일 오후 3:00~오전 12:00
# 뽈살집.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 고집돌우럭 중문점
# 4.7
# 제주특별자치도 서귀포시 특별자치도 일주서로 879
# "1. 대기가 조금 길긴 했지만 역시나 맛집은 맛집이었다."
# 금요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# 토요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# 일요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# 월요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# 화요일 오전 10:00~오후 2:50, 오후 5:00~9:30
# ...

# %%
search2 = "제주시 카페"
cafe = collect_restaurant(search2, 3, 200, 4.2)

cat_list.extend(cafe[0])
pl_list.extend(cafe[1])
sc_list.extend(cafe[2])
ad_list.extend(cafe[3])
bh_list.extend(cafe[4])
comm_list.extend(cafe[5])
# Out:
# 제주시 카페폴더가 존재합니다
# 스폰서 아닙니다.
# 정상 영업합니다.
# 커피파인더
# 4.7
# 제주특별자치도 제주시 특별자치도, 이도이동 서광로32길 20
# 한 줄 리뷰 생략합니다.
# 금요일 오전 10:00~오후 10:00
# 토요일 오전 10:00~오후 10:00
# 일요일 오전 10:00~오후 10:00
# 월요일 오전 10:00~오후 10:00
# 화요일 오전 10:00~오후 10:00
# 수요일 오전 10:00~오후 10:00
# 목요일 오전 10:00~오후 10:00
# 커피파인더.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 노을리 카페
# 4.4
# 제주특별자치도 제주시 특별자치도, 애월읍 애월해안로 656
# 한 줄 리뷰 생략합니다.
# 금요일 오전 9:00~오후 9:00
# 토요일 오전 9:00~오후 9:00
# 일요일 오전 9:00~오후 9:00
# 월요일 오전 9:00~오후 9:00
# 화요일 오전 9:00~오후 9:00
# 수요일 오전 9:00~오후 9:00
# 목요일 오전 9:00~오후 9:00
# 노을리 카페.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 그러므로 part2
# 4.3
# 제주특별자치도 제주시 특별자치도 수목원길 16-14
# 한 줄 리뷰 생략합니다.
# 금요일 오전 10:00~오후 9:00
# 토요일 오전 10:00~오후 9:00
# 일요일 오전 10:00~오후 9:00
# 월요일 휴무일
# 화요일 오전 10:00~오후 9:00
# 수요일 오전 10:00~오후 9:00
# 목요일 오전 10:00~오후 9:00
# 그러므로 part2.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 카페 선흘
# 4.5
# 제주특별자치도 제주시 특별자치도, 선교로 198 KR
# 한 줄 리뷰 생략합니다.
# ...

# %%
search2 = "서귀포시 카페"
cafe = collect_restaurant(search2, 3, 200, 4.2)

cat_list.extend(cafe[0])
pl_list.extend(cafe[1])
sc_list.extend(cafe[2])
ad_list.extend(cafe[3])
bh_list.extend(cafe[4])
comm_list.extend(cafe[5])
# Out:
# 서귀포시 카페폴더가 존재합니다
# 스폰서 아닙니다.
# 정상 영업합니다.
# 라바르
# 4.9
# 제주특별자치도 서귀포시 특별자치도, 중앙로 13
# 한 줄 리뷰 생략합니다.
# 금요일 오전 9:00~오후 11:00
# 토요일 오전 9:00~오후 11:00
# 일요일 오전 9:00~오후 11:00
# 월요일 오전 9:00~오후 11:00
# 화요일 오전 9:00~오후 11:00
# 수요일 오전 9:00~오후 11:00
# 목요일 오전 9:00~오후 11:00
# 라바르.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# Coffee Sketch
# 4.6
# 제주특별자치도 서귀포시 특별자치도, 안덕면 사계리 116-6 KR
# 한 줄 리뷰 생략합니다.
# 금요일 오전 10:00~오후 5:30
# 토요일 오전 10:00~오후 5:30
# 일요일 오전 10:00~오후 5:30
# 월요일 오전 10:00~오후 5:30
# 화요일 오전 10:00~오후 5:30
# 수요일 오전 10:00~오후 5:30
# 목요일 오전 10:00~오전 5:30
# Coffee Sketch.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 휴일로 카페
# 4.4
# 제주특별자치도 서귀포시 안덕면 난드르로 49-65
# 한 줄 리뷰 생략합니다.
# 금요일 오전 10:00~오후 8:00
# 토요일 오전 10:00~오후 8:00
# 일요일 오전 10:00~오후 8:00
# 월요일 오전 10:00~오후 8:00
# 화요일 오전 10:00~오후 8:00
# 수요일 오전 10:00~오후 8:00
# 목요일 오전 10:00~오후 8:00
# 휴일로 카페.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 귤꽃다락
# 4.6
# 제주특별자치도 서귀포시 이어도로1027번길 34
# 한 줄 리뷰 생략합니다.
# ...

# %%
search3 = "제주시 숙소"
hotel = collect_restaurant(search3, 3, 200, 4.2)

cat_list.extend(hotel[0])
pl_list.extend(hotel[1])
sc_list.extend(hotel[2])
ad_list.extend(hotel[3])
bh_list.extend(hotel[4])
comm_list.extend(hotel[5])
# Out:
# 제주시 숙소폴더가 존재합니다
# 스폰서 아닙니다.
# 정상 영업합니다.
# 롯데시티호텔 제주
# 4.3
# 제주특별자치도 제주시 도령로 83
# 한 줄 리뷰 생략합니다.
# 해당 장소에 대한 영업시간 없습니다.
# 롯데시티호텔 제주.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 호텔난타
# 4.4
# 제주특별자치도 제주시 특별자치도, 선돌목동길 56-26
# 한 줄 리뷰 생략합니다.
# 해당 장소에 대한 영업시간 없습니다.
# 호텔난타.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 벤티모 호텔 앤 레지던스 제주
# 4.6
# 제주특별자치도 제주시 특별자치도, 연삼로 14
# 한 줄 리뷰 생략합니다.
# 해당 장소에 대한 영업시간 없습니다.
# 벤티모 호텔 앤 레지던스 제주.jpg 저장 완료
# ------------------------
# -----------------다음 페이지-----------------
# -----------------다음 페이지 없음-----------------
# 제주시 숙소 페이지 크롤링 완료
# 장소이름 3
# 별점 3
# 주소 3
# 영업시간 3
# 리뷰 3

# %%
search3 = "서귀포시 숙소"
hotel = collect_restaurant(search3, 3, 200, 4.2)

cat_list.extend(hotel[0])
pl_list.extend(hotel[1])
sc_list.extend(hotel[2])
ad_list.extend(hotel[3])
bh_list.extend(hotel[4])
comm_list.extend(hotel[5])
# Out:
# 스폰서 아닙니다.
# 정상 영업합니다.
# 서귀포힐즈호텔
# 4.5
# 서귀포시 신서로48번길 50
# 한 줄 리뷰 생략합니다.
# 해당 장소에 대한 영업시간 없습니다.
# 서귀포힐즈호텔.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# Mido Hostel
# 4.5
# 제주특별자치도 서귀포시 서귀동 258-2
# 한 줄 리뷰 생략합니다.
# 해당 장소에 대한 영업시간 없습니다.
# Mido Hostel.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# BK호텔
# 4.3
# 제주특별자치도 서귀포시 서귀동 777-1
# 한 줄 리뷰 생략합니다.
# 해당 장소에 대한 영업시간 없습니다.
# BK호텔.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 백패커스홈
# 4.4
# 제주특별자치도 서귀포시 서귀동 315-3
# 한 줄 리뷰 생략합니다.
# 해당 장소에 대한 영업시간 없습니다.
# 백패커스홈.jpg 저장 완료
# ------------------------
# 스폰서 아닙니다.
# 정상 영업합니다.
# 카사로마호텔
# 4.4
# 제주특별자치도 서귀포시 특별자치도, 태평로 347 KR
# 한 줄 리뷰 생략합니다.
# 해당 장소에 대한 영업시간 없습니다.
# 카사로마호텔.jpg 저장 완료
# ------------------------
# -----------------다음 페이지-----------------
# -----------------다음 페이지 없음-----------------
# 서귀포시 숙소 페이지 크롤링 완료
# 장소이름 5
# 별점 5
# 주소 5
# 영업시간 5
# 리뷰 5

# %%
import pandas as pd
try:  
    # 데이터 저장
    data_dic = {"category":cat_list,
                "place":pl_list,
                "score":sc_list,
                "address":ad_list,
                "bushour":bh_list,
                "summary":comm_list}
    df = pd.DataFrame(data_dic)
    df.to_csv("제주도_맛집_카페_숙소.csv", encoding='utf-8-sig')
    print("제주도_맛집_카페_숙소.csv 파일 변환 완료")

except Exception as e:
    print(f"오류 발생: {e}") 
    print("제주더_맛집_카페_숙소.csv 파일 변환 실패")
# Out:
# 제주도_맛집_카페_숙소.csv 파일 변환 완료
